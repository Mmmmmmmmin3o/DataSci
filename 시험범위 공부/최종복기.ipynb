# %%
import numpy as np

# %%
arr=[[85,92,78],[90,88,95],[76,85,80],[88,90,92]]
student=np.array(arr)

print(f"students array shape >> {student.shape}")
print(f"students array ndim >> {student.ndim}")

# %%
array_1d=np.arange(2.5,5,0.5)

print(f"array_1d dtype >> {array_1d.dtype}")
print(f"array_1d ndim >> {array_1d.ndim}")
print(f"array_1d shape >> {array_1d.shape}")
