# %%
import pandas as pd

df=pd.DataFrame({'data':[1,2,3]}, index=['a','b','c'])
print("Original DataFrame : ")
print(df)
# Out:
# Original DataFrame :
#    data
# a     1
# b     2
# c     3

# %%
df.rename(index={'b':'z'}, inplace=True)

print(df)
# Out:
#    data
# a     1
# z     2
# c     3

# %%
inventory = pd.Series([50, 30, 20, 45, 10, 35], index=['A01', 'A02', 'A03', 'B01', 'B02', 'B03'], name='재고량')

# %%
inventory = inventory.rename(index={"B01": "주요 구역"})

# %%
inventory = pd.Series([50, 30, 20, 45, 10, 35], name='재고량')

# %%
inventory=inventory.rename(index={3:"주요구역"})

# %%
inventory
# Out:
# 0       50
# 1       30
# 2       20
# 주요구역    45
# 4       10
# 5       35
# Name: 재고량, dtype: int64

# %%
import pandas as pd
import numpy as np
arr7 = np.arange(0, 12).reshape((4, 3))

arr7[:]=5

new_column=np.arange(4).reshape((4,1))

arr7[:]=new_column

arr7
# Out:
# array([[0, 0, 0],
#        [1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3]])

# %%
a
